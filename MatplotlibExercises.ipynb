# %% [markdown]
# __Line Plot__<br><br>
#
# The CSV file sales_data.csv contains the following data:<br>
# <img src="nbimages/sales_data.png" width=600 height=500/>
#
# Use the CSV file to construct a Panda DataFrame.<br>
#
# Using the DataFrame compute the total profit of each month and show it using a line plot.<br>
#
# The line plot should look like this.<br><br>
#
# <img src="nbimages/lineplot_1.png" width=400 height=400/>

# %%
import pandas as pd
import matplotlib.pyplot as plt  
import datetime

df = pd.read_csv("datasets/sales_data.csv")
fig=plt.figure() 
ax=fig.add_subplot(1,1,1) # <=> ax=fig.add_subplot(111)
# to be completed
plt.show()# not needed inside a Jupyter notebook
# Out:
# Text(0.5, 0, 'Month number')
# Text(0, 0.5, 'Profit in dollar')
# ...
# Text(0.5, 1.0, 'Company profit per month')
# ...

# %% [markdown]
# __Line Plot__ 2<br><br>
#
# Update the line plot to plot, on the X axis, the month name instead of the month number.<br>
#
# The line plot should look like this.<br><br>
#
# <img src="nbimages/lineplot_2.png" width=400 height=400/>

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
# to be completed
plt.show()# not needed inside a Jupyter notebook
# Out:
# Text(0.5, 0, 'Month')
# Text(0, 0.5, 'Profit in dollar')
# ...
# [Text(0, 0, 'Jan'),
#  Text(0, 0, 'Feb'),
#  Text(0, 0, 'Mar'),
#  Text(0, 0, 'Apr'),
#  Text(0, 0, 'May'),
#  Text(0, 0, 'Jun'),
#  Text(0, 0, 'Jul'),
#  Text(0, 0, 'Aug'),
#  Text(0, 0, 'Sep'),
#  Text(0, 0, 'Oct'),
#  Text(0, 0, 'Nov'),
#  Text(0, 0, 'Dec')]
# Text(0.5, 1.0, 'Company profit per month')
# ...

# %% [markdown]
# __Line Plot__ 3<br><br>
#
# Update the prevous line plot and use the following Style properties:<br>
#
# * Line should a be "dotted line" and the line color should be red.<br>
# * Show legend at the lower right location.<br>
# * Add a circle marker.<br>
# * Line marker color should be red.<br>
# * Line width should be 3.<br>
#
# The line plot should look like this.<br><br>
#
# <img src="nbimages/lineplot_3.png" width=400 height=400/>

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
# to be completed
plt.show()# not needed inside a Jupyter notebook
# Out:
# Text(0.5, 0, 'Month')
# Text(0, 0.5, 'Profit in dollar')
# ...
# [Text(0, 0, 'Jan'),
#  Text(0, 0, 'Feb'),
#  Text(0, 0, 'Mar'),
#  Text(0, 0, 'Apr'),
#  Text(0, 0, 'May'),
#  Text(0, 0, 'Jun'),
#  Text(0, 0, 'Jul'),
#  Text(0, 0, 'Aug'),
#  Text(0, 0, 'Sep'),
#  Text(0, 0, 'Oct'),
#  Text(0, 0, 'Nov'),
#  Text(0, 0, 'Dec')]
# Text(0.5, 1.0, 'Company profit per month')
# ...

# %% [markdown]
# __Multi-line Plot__<br><br>
#
# Plot the number of units sold per month for each product using multiline plots (one line per product).<br>
#
# The multi-line plot should look like this.<br><br>
#
# <img src="nbimages/multiplot.png" width=400 height=400/>

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
# to be completed
plt.show()# not needed inside a Jupyter notebook
# Out:
# Index(['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo',
#        'moisturizer'],
#       dtype='object')
# Text(0.5, 0, 'Month number')
# Text(0, 0.5, 'Sales (number of units)')
# ...
# [Text(0, 0, 'Jan'),
#  Text(0, 0, 'Feb'),
#  Text(0, 0, 'Mar'),
#  Text(0, 0, 'Apr'),
#  Text(0, 0, 'May'),
#  Text(0, 0, 'Jun'),
#  Text(0, 0, 'Jul'),
#  Text(0, 0, 'Aug'),
#  Text(0, 0, 'Sep'),
#  Text(0, 0, 'Oct'),
#  Text(0, 0, 'Nov'),
#  Text(0, 0, 'Dec')]
# Text(0.5, 1.0, 'Sales Data')

# %% [markdown]
# __Scatter Plot__<br><br>
#
# Plot the toothpaste sales data of each month using a scatter plot.<br>
# Add a grid in the plot with dashed lines.
#
# The scatter plot should look like this.<br><br>
#
# <img src="nbimages/scatterplot.png" width=400 height=400/>

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
# to be completed
plt.show() # not needed inside a Jupyter notebook
# Out:
# Index(['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo',
#        'moisturizer'],
#       dtype='object')
# Text(0.5, 0, 'Month number')
# (1, 12)
# ...
# [Text(0, 0, 'Jan'),
#  Text(0, 0, 'Feb'),
#  Text(0, 0, 'Mar'),
#  Text(0, 0, 'Apr'),
#  Text(0, 0, 'May'),
#  Text(0, 0, 'Jun'),
#  Text(0, 0, 'Jul'),
#  Text(0, 0, 'Aug'),
#  Text(0, 0, 'Sep'),
#  Text(0, 0, 'Oct'),
#  Text(0, 0, 'Nov'),
#  Text(0, 0, 'Dec')]
# Text(0.5, 1.0, 'Tooth paste Sales data')

# %% [markdown]
# __Bar Chart__ 1<br><br>
#
# Plot the face cream and the face wash product sales using a bar chart.<br>
# The 2 bar charts should be displayed one on top of the other. <br>
#
# The Bar chart should look like this.<br><br>
#
# <img src="nbimages/barchart1.png" width=400 height=400/>

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)

# to be completed
plt.show()# not needed inside a Jupyter notebook
# Out:
# <BarContainer object of 12 artists>
# <BarContainer object of 12 artists>
# Text(0.5, 0, 'Month number')
# Text(0, 0.5, 'Sales units in number')
# ...
# [Text(0, 0, 'Jan'),
#  Text(0, 0, 'Feb'),
#  Text(0, 0, 'Mar'),
#  Text(0, 0, 'Apr'),
#  Text(0, 0, 'May'),
#  Text(0, 0, 'Jun'),
#  Text(0, 0, 'Jul'),
#  Text(0, 0, 'Aug'),
#  Text(0, 0, 'Sep'),
#  Text(0, 0, 'Oct'),
#  Text(0, 0, 'Nov'),
#  Text(0, 0, 'Dec')]
# Text(0.5, 1.0, 'Facewash and Facecream Sales data')

# %% [markdown]
# __Bar Chart__ 2<br><br>
#
# Plot the face cream and the face wash product sales using a bar chart.<br>
# Two separate adjacent bar charts should now be used to display the number of units sold per month for each product. <br>
#
# The Bar chart should look like this.<br><br>
#
# <img src="nbimages/barchart2.png" width=400 height=400/>

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)

# to be completed
plt.show()# not needed inside a Jupyter notebook
# Out:
# <BarContainer object of 12 artists>
# <BarContainer object of 12 artists>
# Text(0.5, 0, 'Month number')
# Text(0, 0.5, 'Sales units in number')
# ...
# [Text(0, 0, 'Jan'),
#  Text(0, 0, 'Feb'),
#  Text(0, 0, 'Mar'),
#  Text(0, 0, 'Apr'),
#  Text(0, 0, 'May'),
#  Text(0, 0, 'Jun'),
#  Text(0, 0, 'Jul'),
#  Text(0, 0, 'Aug'),
#  Text(0, 0, 'Sep'),
#  Text(0, 0, 'Oct'),
#  Text(0, 0, 'Nov'),
#  Text(0, 0, 'Dec')]
# Text(0.5, 1.0, 'Facewash and Facecream Sales data')

# %% [markdown]
# __Pie Chart__<br><br>
# Calculate total sale data for each product and show it using a _Pie chart_.<br>
# Note: In the Pie chart display, for each product, the percentage of units sold per year.<br>
#
# The Pie chart should look like this.<br><br>
#
# <img src="nbimages/piechart.png" width=400 height=400/>

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
# to be completed
plt.show()# not needed inside a Jupyter notebook
# Out:
# (-0.05, 1.05, -0.05, 1.05)
# ([<matplotlib.patches.Wedge at 0x12b4bac8>,
# ...
#  [Text(1.0191857113582774, 0.4138363030995739, 'facecream'),
#   Text(0.6140655913722997, 0.912646398936953, 'facewash'),
#   Text(-0.4252111998343268, 1.0144926986112084, 'toothpaste'),
#   Text(-0.6978920809686103, -0.8502626907734472, 'bathingsoap'),
#   Text(0.8424027164269658, -0.7073596421598204, 'shampoo'),
#   Text(1.0764907254787095, -0.226202824823922, 'moisturizer')],
#  [Text(0.5559194789226967, 0.22572889259976756, '12.3%'),
#   Text(0.3349448680212543, 0.4978071266928834, '6.6%'),
#   Text(-0.2319333817278146, 0.5533596537879318, '24.9%'),
#   Text(-0.38066840780106015, -0.4637796495127893, '40.6%'),
#   Text(0.459492390778345, -0.3858325320871747, '9.0%'),
#   Text(0.5871767593520233, -0.12338335899486653, '6.6%')])
# Text(0.5, 1.0, 'Sales data')

# %% [markdown]
# __Stack Plot__<br><br>
# Read all product sales data and show it using a __stack plot__.<br>
# The Stack plot should look like this.<br><br>
# <img src="nbimages/stackplot.png" width=400 height=400/>

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)

# to be completed

plt.show()
# Out:
# ...
# Text(0.5, 0, 'Month Number')
# Text(0, 0.5, 'Sales units in Number')
# Text(0.5, 1.0, 'Sales data')
